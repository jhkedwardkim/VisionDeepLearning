# %%
# %matplotlib inline
import cv2 as cv
import matplotlib.pyplot as plt

# %%
file_name = 'soccer.jpg'
img=cv.imread(file_name) 
if img is None:
    sys.exit('파일({0})을 찾을 수 없습니다.'.format(file_name))
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
h=cv.calcHist([img],[2],None,[256],[0,256]) # 2번 채널인 R 채널에서 히스토그램 구함
plt.plot(h,color='r',linewidth=1)

# %%
h_gray=cv.calcHist([gray],[0],None,[256],[0,256]) # 2번 채널인 R 채널에서 히스토그램 구함
plt.plot(h_gray,color='r',linewidth=1)
